# %%
# ============================================================
# SETUP PROJECT ENVIRONMENT — LOCAL EXECUTION
# ============================================================

import os
from pyspark.sql import SparkSession

# %%
# -----------------------------------------
# 1. Initialize Spark Session
# -----------------------------------------
spark = (
    SparkSession.builder
        .appName("F1-Analytics-Environment-Setup")
        .master("local[*]")
        .config("spark.sql.shuffle.partitions", "8")
        .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/06/09 12:42:08 WARN Utils: Your hostname, Manohars-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.68.78.178 instead (on interface en0)
# 26/06/09 12:42:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/09 12:42:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# -----------------------------------------
# 2. Define Base Paths
# -----------------------------------------
BASE_PATH = "/Users/manoharazalki/F1-Analytics/data"

LANDING_PATH     = f"{BASE_PATH}/landing"
BRONZE_PATH      = f"{BASE_PATH}/bronze"
SILVER_PATH      = f"{BASE_PATH}/silver"
GOLD_PATH        = f"{BASE_PATH}/gold"
INCREMENTAL_PATH = f"{BASE_PATH}/incremental"
CONTROL_PATH     = f"{BASE_PATH}/control"

# %%
# -----------------------------------------
# 3. Define Base Paths
# -----------------------------------------
paths = [
    LANDING_PATH,
    BRONZE_PATH,
    SILVER_PATH,
    GOLD_PATH,
    INCREMENTAL_PATH,
    CONTROL_PATH
]

for p in paths:
    os.makedirs(p, exist_ok=True)

print("✔ All project directories created successfully.")

# %%
# -----------------------------------------
# 4. Define Base Paths
# -----------------------------------------
print("===== F1 Analytics Local Environment Setup =====")
print(f"Landing:     {LANDING_PATH}")
print(f"Bronze:      {BRONZE_PATH}")
print(f"Silver:      {SILVER_PATH}")
print(f"Gold:        {GOLD_PATH}")
print(f"Incremental: {INCREMENTAL_PATH}")
print(f"Control:     {CONTROL_PATH}")
print("================================================")
# Out:
# ===== F1 Analytics Local Environment Setup =====
# Landing:     /Users/manoharazalki/F1-Analytics/data/landing
# Bronze:      /Users/manoharazalki/F1-Analytics/data/bronze
# Silver:      /Users/manoharazalki/F1-Analytics/data/silver
# Gold:        /Users/manoharazalki/F1-Analytics/data/gold
# Incremental: /Users/manoharazalki/F1-Analytics/data/incremental
# Control:     /Users/manoharazalki/F1-Analytics/data/control
# ...
